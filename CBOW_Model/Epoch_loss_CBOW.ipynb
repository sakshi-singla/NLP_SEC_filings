# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
path = "/ifs/gsb/usf_interns/Saved_models_CBOW_GPU/loss_formated.csv"

# %%
df=pd.read_csv(path,header=None)
df=df.rename(columns={0: "epoch", 1: "loss"})

# %%
df
# Out:
#     epoch          loss
# 0       0  1.073586e+06
# 1       1  9.281997e+05
# 2       2  8.907077e+05
# 3       3  8.690921e+05
# 4       4  8.541092e+05
# 5       5  8.427514e+05
# 6       6  8.336472e+05
# 7       7  8.260665e+05
# 8       8  8.195835e+05
# 9       9  8.139265e+05
# 10     10  8.089097e+05
# 11     11  8.044012e+05
# 12     12  8.003055e+05
# 13     13  7.965522e+05
# 14     14  7.930883e+05
# 15     15  7.898731e+05
# 16     16  7.868747e+05
# 17     17  7.840678e+05
# 18     18  7.814317e+05
# 19     19  7.789491e+05
# 20     20  7.766054e+05
# 21     21  7.743878e+05
# 22     22  7.722855e+05
# 23     23  7.702885e+05
# 24     24  7.683882e+05
# 25     25  7.665769e+05
# 26     26  7.648476e+05
# 27     27  7.631941e+05
# 28     28  7.616109e+05
# 29     29  7.600929e+05
# 30     30  7.586355e+05
# 31     31  7.572348e+05
# 32     32  7.558869e+05
# 33     33  7.545884e+05
# 34     34  7.533364e+05
# 35     35  7.521279e+05

# %%
plt.scatter(df['epoch'], df['loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
